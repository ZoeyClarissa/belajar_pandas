# %% [markdown]
# Week 2 Pandas

# %% [markdown]
# #05: Membalik urutan baris dan kolom pada Data Frame

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.3.3
# 2.3.4

# %% [markdown]
# Persiapan Data Frame

# %%
n_rows = 5
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 10, size=(n_rows, n_cols)), 
                  columns=cols)
df
# Out:
#    A  B  C  D  E
# 0  1  4  2  7  5
# 1  4  3  2  6  6
# 2  9  7  8  2  3
# 3  6  9  8  3  5
# 4  5  6  4  6  3

# %% [markdown]
# Membalik urutan kolom

# %%
df.loc[:, ::-1]
# Out:
#    E  D  C  B  A
# 0  5  7  2  4  1
# 1  6  6  2  3  4
# 2  3  2  8  7  9
# 3  5  3  8  9  6
# 4  3  6  4  6  5

# %% [markdown]
# Membalik urutan baris

# %%
df.loc[::-1]
# Out:
#    A  B  C  D  E
# 4  5  6  4  6  3
# 3  6  9  8  3  5
# 2  9  7  8  2  3
# 1  4  3  2  6  6
# 0  1  4  2  7  5

# %% [markdown]
# Membalik urutan baris dan melakukan penyesuaian ulang index

# %%
df.loc[::-1].reset_index(drop=True)
# Out:
#    A  B  C  D  E
# 0  5  6  4  6  3
# 1  6  9  8  3  5
# 2  9  7  8  2  3
# 3  4  3  2  6  6
# 4  1  4  2  7  5

# %% [markdown]
# #06: Mengganti nama (label) kolom pada Data Frame

# %% [markdown]
# Persiapan Data Frame

# %%
n_rows = 5
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 10, size=(n_rows, n_cols)), 
                  columns=cols)
df
# Out:
#    A  B  C  D  E
# 0  2  4  5  8  7
# 1  6  5  7  9  7
# 2  1  2  4  9  3
# 3  7  1  1  9  9
# 4  3  1  9  5  9

# %% [markdown]
# Mengganti nama (label) untuk sebuah kolom pada Data Frame

# %%
df.rename(columns={'C':'Hobi'})
# Out:
#    A  B  Hobi  D  E
# 0  2  4     5  8  7
# 1  6  5     7  9  7
# 2  1  2     4  9  3
# 3  7  1     1  9  9
# 4  3  1     9  5  9

# %% [markdown]
# Mengganti nama (label) untuk banyak kolom pada Data Frame

# %%
df.rename(columns={'A':'Nama', 'B':'Alamat', 'D':'Kota'})
# Out:
#    Nama  Alamat  C  Kota  E
# 0     2       4  5     8  7
# 1     6       5  7     9  7
# 2     1       2  4     9  3
# 3     7       1  1     9  9
# 4     3       1  9     5  9

# %% [markdown]
# #07: Menghapus (drop) missing values (NaN)

# %% [markdown]
# Persiapan Data Frame

# %%
n_rows = 30
n_cols = 4
cols = ['A', 'B', 'C', 'D']

df = pd.DataFrame(np.random.randn(n_rows, n_cols), columns=cols)

nan_mask = np.random.rand(n_rows, n_cols) < 0.2
df[nan_mask] = np.nan

df = df.reset_index()
df.head()
# Out:
#    index         A         B         C         D
# 0      0  0.994783       NaN  0.265351       NaN
# 1      1  0.123165 -0.199647 -0.000258 -0.893141
# 2      2 -0.181440  1.375093  0.029293  0.799125
# 3      3  1.398520  0.550029 -0.400392 -1.092522
# 4      4  0.230166  0.714318 -1.823903 -0.003355

# %%
df = df.rename(columns={'index':'Z'})
df.head()
# Out:
#    Z         A         B         C         D
# 0  0  0.994783       NaN  0.265351       NaN
# 1  1  0.123165 -0.199647 -0.000258 -0.893141
# 2  2 -0.181440  1.375093  0.029293  0.799125
# 3  3  1.398520  0.550029 -0.400392 -1.092522
# 4  4  0.230166  0.714318 -1.823903 -0.003355

# %%
df_backup = df.copy(deep=True)

# %% [markdown]
# Menghapus (drop) setiap kolom yang mengandung missing values

# %%
df = df.dropna(axis='columns') 
df.head()
# Out:
#    Z
# 0  0
# 1  1
# 2  2
# 3  3
# 4  4

# %% [markdown]
# Menghapus (drop) setiap baris yang mengandung missing values

# %%
df = df_backup.copy(deep=True)
df = df.dropna(axis='rows')
df.head()
# Out:
#      Z         A         B         C         D
# 1    1  0.123165 -0.199647 -0.000258 -0.893141
# 2    2 -0.181440  1.375093  0.029293  0.799125
# 3    3  1.398520  0.550029 -0.400392 -1.092522
# 4    4  0.230166  0.714318 -1.823903 -0.003355
# 12  12  0.260091 -0.486174  1.079145  0.577820

# %% [markdown]
# Persentase missing values untuk tiap kolom

# %%
df = df_backup.copy(deep=True)
df.isna().mean()
# Out:
# Z    0.000000
# A    0.133333
# B    0.266667
# C    0.166667
# D    0.300000
# dtype: float64

# %% [markdown]
# Menghapus (drop) setiap kolom yang mengandung missing values berdasarkan threshold

# %%
treshold = len(df) * 0.9
df = df.dropna(thresh=treshold, axis='columns')
df.head()
# Out:
#    Z
# 0  0
# 1  1
# 2  2
# 3  3
# 4  4

# %% [markdown]
# #08: Memeriksa kesamaan antar dua buah kolom (Series) pada Data Frame

# %% [markdown]
# Persiapan Data Frame

# %%
data = {'A':[15, 15, 18, np.nan, 12], 
        'B':[15, 15, 18, np.nan, 12]}

df = pd.DataFrame(data)
df
# Out:
#       A     B
# 0  15.0  15.0
# 1  15.0  15.0
# 2  18.0  18.0
# 3   NaN   NaN
# 4  12.0  12.0

# %% [markdown]
# Mengenal Pandas Series

# %%
df['A']
# Out:
# 0    15.0
# 1    15.0
# 2    18.0
# 3     NaN
# 4    12.0
# Name: A, dtype: float64

# %%
type(df['A'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Memeriksa kesamaan dengan operator ==

# %%
df['A'] == df['B']
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# dtype: bool

# %% [markdown]
# Memeriksa kesamaan dengan method equals()

# %%
df['A'].equals(df['B'])
# Out:
# True

# %% [markdown]
# Memeriksa kesamaan antar dua Data Frame

# %%
df1 = df.copy(deep=True)

df.equals(df1)
# Out:
# True

# %%
df == df1
# Out:
#        A      B
# 0   True   True
# 1   True   True
# 2   True   True
# 3  False  False
# 4   True   True
